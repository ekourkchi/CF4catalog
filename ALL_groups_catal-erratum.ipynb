# %%
import sys
import time
import os
import subprocess
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
from scipy import interpolate
from scipy import polyval, polyfit
from scipy.optimize import curve_fit
from scipy import odr
import pylab as py
from matplotlib import gridspec
import sklearn.datasets as ds
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import corner
import emcee
import scipy.optimize as op
from scipy.linalg import cholesky, inv,det
from scipy.optimize import minimize
import random
from astropy.table import Table, Column
import pandas as pd
import numpy as np
from datetime import datetime
import time

import warnings
warnings.filterwarnings("ignore")

# %%
## This function allows to execute the OS commands
def xcmd(cmd, verbose=True):
    """Runs an OS command
    :param cmd: terminal command
    :type cmd: ``str``
    :param verbose: printing the details, default True 
    :type verbose: ``boolean``
    :return: OS outputs
    :rtype: ``str``
    """

    if verbose: print('\n'+cmd)

    tmp=os.popen(cmd)
    output=''
    for x in tmp: output+=x
    if 'abort' in output:
        failure=True
    else:
        failure=tmp.close()
    if False:
        print('execution of %s failed' % cmd)
        print('error is as follows', output)
        sys.exit()
    else:
        return output

# %%
# This function works with both dbtable and the catalog header name on EDD
def get_catal(catal_string, infoFile="../bar_files/catalogs_info.dat", bars_folder='../bar_files/'):
    
    xcmd("scp -r ehsan@arp.ifa.hawaii.edu:~/catalogs_info.dat ../bar_files/.", verbose=True)

    with open(infoFile, "r") as f:
        lines = f.readlines()


        try:
            for i, line in enumerate(lines):
                if catal_string in line:
                    
                    while not "begin" in line:
                        i-=1
                        line = lines[i]
                    while not "filename" in line:
                        i+=1
                        line=lines[i]

                    fname_string = line
                    break
        except: 
            return "", []
            
        catal_columns = []
        
        try:
            while not "column" in line:
                i+=1
                line=lines[i]
            while not 'end' in line:
                catal_columns.append(line.split("=>")[1].split("|")[0].strip())
                i+=1
                line=lines[i]
                
        except:
            print("why")
            return "", []


    catal_file_name = fname_string.split("=>")[1].strip("\n").strip("")
    
    xcmd("scp -r ehsan@arp.ifa.hawaii.edu:~/bar_files/"+catal_file_name+"  "+bars_folder+"/.", verbose=True)
    
    data = pd.read_csv(bars_folder+catal_file_name, names=catal_columns, delimiter='|')
    
    for col in catal_columns:
        if col.upper()=="PGC":
            break
    
    data.rename(columns={col:col.upper()}, inplace=True)
    data = data.set_index('PGC')
    
    # taking care of empty string
    data = data.replace(r'^\s*$', np.nan, regex=True)
    
    if "1PGC" in data.columns:
        data = data.rename(columns={"1PGC": "PGC1"})
    else:
        data["PGC1"] = data.index.values
    
    if "av_flag" in data.columns:
        data = data[data.av_flag==0]
    
    
    return data

# %%
def make_data(data, catalogs, catal_data, catal_key, catal_DM="DM", catal_eDM="eDM", delta=0, \
              cols=["Vcmb","Nest"]):
    
    if not catal_key in catalogs and not catal_key in data:
        data[catal_key] = catal_data[["PGC1", catal_DM, catal_eDM]+cols]
        data[catal_key] = data[catal_key].rename(columns={"PGC1": "PGC1_"+catal_key})
        data[catal_key] = data[catal_key].rename(columns={catal_DM: "DM_"+catal_key})
        data[catal_key] = data[catal_key].rename(columns={catal_eDM: "eDM_"+catal_key})
        
        for col in cols:
            data[catal_key] = data[catal_key].rename(columns={col: col+"_"+catal_key})
        
        catalogs.append(catal_key)
        
        data[catal_key]["DM_"+catal_key] += delta
        
    else:
        print("This catalog has been already imported ...")
        print("Use a different key than "+catal_key)
    
    return data, catalogs

# %%
#################################################################
def Vh2V3k(el,b, Vh):
  
    alpha = np.pi / 180.
    cosb = np.cos(b*alpha)
    sinb = np.sin(b*alpha)
    cosl = np.cos(el*alpha)
    sinl = np.sin(el*alpha)
    
    v3k = Vh-25.2*cosl*cosb-245.7*sinl*cosb+276.8*sinb

    return v3k

#################################################################

def Vcmb2Vmod(Vcmb, omegam=0.27):
    
    omegal=1.-omegam
    c=299800.
    z=Vcmb/c
    q0=0.5*(omegam-2.*omegal)
    fmod=1.+0.5*(1.-q0)*z-(1./6)*(1.-q0-3.*q0**2+1.)*z**2
    Vmod=c*z*fmod

    return Vmod
#################################################################

def Vh2Vls(el,b, Vh):
  
    alpha = np.pi / 180.
    cosb = np.cos(b*alpha)
    sinb = np.sin(b*alpha)
    cosl = np.cos(el*alpha)
    sinl = np.sin(el*alpha)
    
    vls = Vh-26.*cosl*cosb+317.*sinl*cosb-8.*sinb

    return vls
#################################################################

# %%
catalogs = []

def prepare_data(df, catal_name, col_names, col2=[]):
    
    cat = catal_name
    
    if col_names is None:
        return df
    else:
        df["DM_"+cat]   = df[col_names[0]]
        df["eDM_"+cat]  = df[col_names[1]]
        df['Vcmb_'+cat] = df[col_names[2]]
        df['gSGL_'+cat] = df[col_names[3]]
        df['gSGB_'+cat] = df[col_names[4]]
       
    df["eDM_"+cat][df["DM_"+cat]==0] = np.nan
    df["DM_"+cat][df["DM_"+cat]==0] = np.nan
    df['Vcmb_'+cat][df["DM_"+cat].isna()] = np.nan
    
    columns = ["DM", "eDM", "Vcmb", "gSGL", "gSGB"]
    
    if not catal_name in catalogs:
        catalogs.append(catal_name)
    
    return df[[col+'_'+cat for col in columns]+col2]

# %%
catal_dbtable = "kcf4allcalgp"
data = get_catal(catal_dbtable)

df = data[["DM", "N"]].rename(columns={"N":"Nc", "DM":"DMcal"})

df
# Out:
#          DMcal  Nc
# PGC
# 35       29.73   1
# 143      24.91   1
# 218      30.73   1
# 388      29.65   1
# 591      29.51   1
# ...        ...  ..
# 5072711  29.68   1
# 5072714  29.42   1
# 5808772  30.07   1
# 5809449  30.13   1
# 6726347  28.82   1
#
# [336 rows x 2 columns]

# %%
catal_dbtable = "kcf4sniagroup"
catal = get_catal(catal_dbtable)

data = prepare_data(catal, 'SNIa', ['DM', 'eDM', 'gVcmb', 'gSGL', 'gSGB'], ["N"]).rename(columns={"N":"Nsn"})

print(len(data))

df = df.join(data, how='outer')

df.head()
# Out:
# 945
#      DMcal   Nc  DM_SNIa  eDM_SNIa  Vcmb_SNIa  gSGL_SNIa  gSGB_SNIa  Nsn
# PGC
# 35   29.73  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 143  24.91  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 218  30.73  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 250    NaN  NaN    35.05      0.13     6894.0   316.3212    17.6719  1.0
# 282    NaN  NaN    36.04      0.11    10921.0   282.0792     8.9703  1.0

# %%
catal_dbtable = "kcf4fpgroup"
catal = get_catal(catal_dbtable)

data = prepare_data(catal, 'FP', ['DM_w', 'eDM', 'gVcmb', 'gSGL', 'gSGB'], ["Nfp"])

print(len(data))

df = df.join(data, how='outer')

df.head()
# Out:
# 27697
#      DMcal   Nc  DM_SNIa  eDM_SNIa  Vcmb_SNIa  gSGL_SNIa  gSGB_SNIa  Nsn  \
# PGC
# 35   29.73  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 75     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 115    NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 123    NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 143  24.91  1.0      NaN       NaN        NaN        NaN        NaN  NaN
#
#       DM_FP  eDM_FP  Vcmb_FP   gSGL_FP  gSGB_FP  Nfp
# PGC
# 35      NaN     NaN      NaN       NaN      NaN  NaN
# 75   36.465   0.299  11521.0  251.2392  -1.4353  5.0
# 115  36.270   0.520  14051.0  288.5214  11.5692  1.0
# 123  35.920   0.500  10964.0  278.4600   8.4002  1.0
# 143     NaN     NaN      NaN       NaN      NaN  NaN

# %%
catal_dbtable = "kcf4tfgroup"
catal = get_catal(catal_dbtable)

data = prepare_data(catal, 'TFR', ['DM_w', 'eDM', 'gVcmb', 'gSGL', 'gSGB'], ["Ntf"])

print(len(data))

df = df.join(data, how='outer')

df.head()
# Out:
# 10188
#      DMcal   Nc  DM_SNIa  eDM_SNIa  Vcmb_SNIa  gSGL_SNIa  gSGB_SNIa  Nsn  \
# PGC
# 12     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 14     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 16     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 35   29.73  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 55     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
#
#      DM_FP  eDM_FP  Vcmb_FP  gSGL_FP  gSGB_FP  Nfp  DM_TFR  eDM_TFR  Vcmb_TFR  \
# PGC
# 12     NaN     NaN      NaN      NaN      NaN  NaN   34.97     0.41    6179.0
# 14     NaN     NaN      NaN      NaN      NaN  NaN   36.07     0.38   11474.0
# 16     NaN     NaN      NaN      NaN      NaN  NaN   34.63     0.45    5354.0
# 35     NaN     NaN      NaN      NaN      NaN  NaN     NaN      NaN       NaN
# 55     NaN     NaN      NaN      NaN      NaN  NaN   34.22     0.39    4466.0
#
#      gSGL_TFR  gSGB_TFR  Ntf
# PGC
# 12   286.4249   11.3510  1.0
# 14   300.8070   15.3909  1.0
# 16   287.6120   11.7030  1.0
# 35        NaN       NaN  NaN
# 55   327.0996   19.7763  1.0

# %%
catal_dbtable = "kcf4sbfgroup"
catal = get_catal(catal_dbtable)

data = prepare_data(catal, 'SBFm', ['DMm_w', 'eDMm', 'gVcmb', 'gSGL', 'gSGB'], ["Nmain"]).rename(columns={"Nmain":"Nsbfo"})
data = data.dropna()
print(len(data))

df = df.join(data, how='outer')

df.head()
# Out:
# 177
#      DMcal   Nc  DM_SNIa  eDM_SNIa  Vcmb_SNIa  gSGL_SNIa  gSGB_SNIa  Nsn  \
# PGC
# 12     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 14     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 16     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 35   29.73  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 55     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
#
#      DM_FP  eDM_FP  ...  Vcmb_TFR  gSGL_TFR  gSGB_TFR  Ntf  DM_SBFm  eDM_SBFm  \
# PGC                 ...
# 12     NaN     NaN  ...    6179.0  286.4249   11.3510  1.0      NaN       NaN
# 14     NaN     NaN  ...   11474.0  300.8070   15.3909  1.0      NaN       NaN
# 16     NaN     NaN  ...    5354.0  287.6120   11.7030  1.0      NaN       NaN
# 35     NaN     NaN  ...       NaN       NaN       NaN  NaN      NaN       NaN
# 55     NaN     NaN  ...    4466.0  327.0996   19.7763  1.0      NaN       NaN
#
#      Vcmb_SBFm  gSGL_SBFm  gSGB_SBFm  Nsbfo
# PGC
# 12         NaN        NaN        NaN    NaN
# 14         NaN        NaN        NaN    NaN
# 16         NaN        NaN        NaN    NaN
# 35         NaN        NaN        NaN    NaN
# 55         NaN        NaN        NaN    NaN
#
# [5 rows x 26 columns]

# %%
catal_dbtable = "kcf4sbfgroup"
catal = get_catal(catal_dbtable)

data = prepare_data(catal, 'SBFir', ['DMir_w', 'eDMir', 'gVcmb', 'gSGL', 'gSGB'], ["Nir"]).rename(columns={"Nir":"Nsbfi"})
data = data.dropna()
print(len(data))

df = df.join(data, how='outer')

df.head()
# Out:
# 57
#      DMcal   Nc  DM_SNIa  eDM_SNIa  Vcmb_SNIa  gSGL_SNIa  gSGB_SNIa  Nsn  \
# PGC
# 12     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 14     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 16     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 35   29.73  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 55     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
#
#      DM_FP  eDM_FP  ...  Vcmb_SBFm  gSGL_SBFm  gSGB_SBFm  Nsbfo  DM_SBFir  \
# PGC                 ...
# 12     NaN     NaN  ...        NaN        NaN        NaN    NaN       NaN
# 14     NaN     NaN  ...        NaN        NaN        NaN    NaN       NaN
# 16     NaN     NaN  ...        NaN        NaN        NaN    NaN       NaN
# 35     NaN     NaN  ...        NaN        NaN        NaN    NaN       NaN
# 55     NaN     NaN  ...        NaN        NaN        NaN    NaN       NaN
#
#      eDM_SBFir  Vcmb_SBFir  gSGL_SBFir  gSGB_SBFir  Nsbfi
# PGC
# 12         NaN         NaN         NaN         NaN    NaN
# 14         NaN         NaN         NaN         NaN    NaN
# 16         NaN         NaN         NaN         NaN    NaN
# 35         NaN         NaN         NaN         NaN    NaN
# 55         NaN         NaN         NaN         NaN    NaN
#
# [5 rows x 32 columns]

# %%
catal_dbtable = "kcf4sniigroup"
catal = get_catal(catal_dbtable)

data = prepare_data(catal, 'SNII', ['DM', 'eDM', 'Vcmb', 'SGL', 'SGB'])

print(len(data))

df = df.join(data, how='outer')

df.head()
# Out:
# 94
#      DMcal   Nc  DM_SNIa  eDM_SNIa  Vcmb_SNIa  gSGL_SNIa  gSGB_SNIa  Nsn  \
# PGC
# 12     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 14     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 16     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
# 35   29.73  1.0      NaN       NaN        NaN        NaN        NaN  NaN
# 55     NaN  NaN      NaN       NaN        NaN        NaN        NaN  NaN
#
#      DM_FP  eDM_FP  ...  eDM_SBFir  Vcmb_SBFir  gSGL_SBFir  gSGB_SBFir  Nsbfi  \
# PGC                 ...
# 12     NaN     NaN  ...        NaN         NaN         NaN         NaN    NaN
# 14     NaN     NaN  ...        NaN         NaN         NaN         NaN    NaN
# 16     NaN     NaN  ...        NaN         NaN         NaN         NaN    NaN
# 35     NaN     NaN  ...        NaN         NaN         NaN         NaN    NaN
# 55     NaN     NaN  ...        NaN         NaN         NaN         NaN    NaN
#
#      DM_SNII  eDM_SNII  Vcmb_SNII  gSGL_SNII  gSGB_SNII
# PGC
# 12       NaN       NaN        NaN        NaN        NaN
# 14       NaN       NaN        NaN        NaN        NaN
# 16       NaN       NaN        NaN        NaN        NaN
# 35       NaN       NaN        NaN        NaN        NaN
# 55       NaN       NaN        NaN        NaN        NaN
#
# [5 rows x 37 columns]

# %%
def merge_col(df, col='Vcmb'):
    
    columns = [x for x in df.columns.values if col in x]
    df[col] = df[columns].mean(axis=1)
    
    print(columns)
    df = df.drop(columns=columns)
    
    
    return df 


for col in ["Vcmb", "gSGL", "gSGB"]:
    df = merge_col(df, col=col)
# Out:
# ['Vcmb_SNIa', 'Vcmb_FP', 'Vcmb_TFR', 'Vcmb_SBFm', 'Vcmb_SBFir', 'Vcmb_SNII']
# ['gSGL_SNIa', 'gSGL_FP', 'gSGL_TFR', 'gSGL_SBFm', 'gSGL_SBFir', 'gSGL_SNII']
# ['gSGB_SNIa', 'gSGB_FP', 'gSGB_TFR', 'gSGB_SBFm', 'gSGB_SBFir', 'gSGB_SNII']

# %%
df = df.rename(columns={'gSGL':'SGL', 'gSGB':'SGB'})


df.head()
# Out:
#      DMcal   Nc  DM_SNIa  eDM_SNIa  Nsn  DM_FP  eDM_FP  Nfp  DM_TFR  eDM_TFR  \
# PGC
# 12     NaN  NaN      NaN       NaN  NaN    NaN     NaN  NaN   34.97     0.41
# 14     NaN  NaN      NaN       NaN  NaN    NaN     NaN  NaN   36.07     0.38
# 16     NaN  NaN      NaN       NaN  NaN    NaN     NaN  NaN   34.63     0.45
# 35   29.73  1.0      NaN       NaN  NaN    NaN     NaN  NaN     NaN      NaN
# 55     NaN  NaN      NaN       NaN  NaN    NaN     NaN  NaN   34.22     0.39
#
#      ...  eDM_SBFm Nsbfo DM_SBFir eDM_SBFir Nsbfi DM_SNII eDM_SNII     Vcmb  \
# PGC  ...
# 12   ...       NaN   NaN      NaN       NaN   NaN     NaN      NaN   6179.0
# 14   ...       NaN   NaN      NaN       NaN   NaN     NaN      NaN  11474.0
# 16   ...       NaN   NaN      NaN       NaN   NaN     NaN      NaN   5354.0
# 35   ...       NaN   NaN      NaN       NaN   NaN     NaN      NaN      NaN
# 55   ...       NaN   NaN      NaN       NaN   NaN     NaN      NaN   4466.0
#
#           SGL      SGB
# PGC
# 12   286.4249  11.3510
# 14   300.8070  15.3909
# 16   287.6120  11.7030
# 35        NaN      NaN
# 55   327.0996  19.7763
#
# [5 rows x 22 columns]

# %%
df = df.astype("float64")

# %%
catalogs
# Out:
# ['SNIa', 'FP', 'TFR', 'SBFm', 'SBFir', 'SNII']

# %%
myDict = {}

myDict["SNIa"] = 0.
myDict["FP"] = 0.128
myDict["TFR"] = 0.151
myDict["SBFm"] = 0.091
myDict["SBFir"] = 0.087
myDict["SNII"] = -0.094


for cat in catalogs:
    df['DM_'+cat] += myDict[cat]
    df['w_'+cat] = (1.-0)/df['eDM_'+cat]**2
    df['w_'+cat] = df['w_'+cat].apply(lambda x: x if x!=0 else np.nan)
    df['e_'+cat] = (1.-0)*df['eDM_'+cat]
    df['e_'+cat] = df['e_'+cat].apply(lambda x: x if x!=0 else np.nan)
    df['xw_'+cat] = (df['DM_'+cat])*df['w_'+cat]

sw = ['w_'+cat for cat in catalogs]
ee = ['e_'+cat for cat in catalogs]
sx = ['xw_'+cat for cat in catalogs]

Err2 = 1./df[sw].sum(axis=1)

df["eDM_av"] = np.sqrt(Err2)
df["DM_av"]  = df[sx].sum(axis=1)*Err2

# %%
for cat in catalogs:
    edm = 'eDM_'+cat
    dm = 'DM_'+cat
    
    ## don't perform the adjsutments on the individual cataloged distances
    df['DM_'+cat] -= myDict[cat]
    
    print(dm, edm)
    
    df[edm] = df.apply(lambda x: x[edm] if x[dm]!=0 else np.nan, axis=1)
    df[dm] = df.apply(lambda x: x[dm] if x[dm]!=0 else np.nan, axis=1)
# Out:
# DM_SNIa eDM_SNIa
# DM_FP eDM_FP
# DM_TFR eDM_TFR
# DM_SBFm eDM_SBFm
# DM_SBFir eDM_SBFir
# DM_SNII eDM_SNII

# %%
columns = ["DM_av", "eDM_av", "Vcmb", "SGL", "SGB", "Nc", "DMcal"]
N_col = ["Nsn", "Nfp", "Ntf", "Nsbfo", "Nsbfi"]
for i, cat in enumerate(catalogs):
    
    if i<5:
        columns += [N_col[i]]
    columns += ['DM_'+cat]
    columns += ['eDM_'+cat]
    
    
    
df = df[columns]

df.head()
# Out:
#       DM_av  eDM_av     Vcmb       SGL      SGB   Nc  DMcal  Nsn  DM_SNIa  \
# PGC
# 12   35.121    0.41   6179.0  286.4249  11.3510  NaN    NaN  NaN      NaN
# 14   36.221    0.38  11474.0  300.8070  15.3909  NaN    NaN  NaN      NaN
# 16   34.781    0.45   5354.0  287.6120  11.7030  NaN    NaN  NaN      NaN
# 35      NaN     inf      NaN       NaN      NaN  1.0  29.73  NaN      NaN
# 55   34.371    0.39   4466.0  327.0996  19.7763  NaN    NaN  NaN      NaN
#
#      eDM_SNIa  ...  DM_TFR  eDM_TFR  Nsbfo  DM_SBFm  eDM_SBFm  Nsbfi  \
# PGC            ...
# 12        NaN  ...   34.97     0.41    NaN      NaN       NaN    NaN
# 14        NaN  ...   36.07     0.38    NaN      NaN       NaN    NaN
# 16        NaN  ...   34.63     0.45    NaN      NaN       NaN    NaN
# 35        NaN  ...     NaN      NaN    NaN      NaN       NaN    NaN
# 55        NaN  ...   34.22     0.39    NaN      NaN       NaN    NaN
#
#      DM_SBFir  eDM_SBFir  DM_SNII  eDM_SNII
# PGC
# 12        NaN        NaN      NaN       NaN
# 14        NaN        NaN      NaN       NaN
# 16        NaN        NaN      NaN       NaN
# 35        NaN        NaN      NaN       NaN
# 55        NaN        NaN      NaN       NaN
#
# [5 rows x 24 columns]

# %%
cc = []
for c in df.columns[:3]:
    cc.append(c)
cc += ["RA", "DEC", "GL", "GB"]
for c in df.columns[3:]:
    cc.append(c)

cc
# Out:
# ['DM_av',
#  'eDM_av',
#  'Vcmb',
#  'RA',
#  'DEC',
#  'GL',
#  'GB',
#  'SGL',
#  'SGB',
#  'Nc',
#  'DMcal',
#  'Nsn',
#  'DM_SNIa',
#  'eDM_SNIa',
#  'Nfp',
#  'DM_FP',
#  'eDM_FP',
#  'Ntf',
#  'DM_TFR',
#  'eDM_TFR',
#  'Nsbfo',
#  'DM_SBFm',
#  'eDM_SBFm',
#  'Nsbfi',
#  'DM_SBFir',
#  'eDM_SBFir',
#  'DM_SNII',
#  'eDM_SNII']

# %%
from kapteyn import wcs

super2celestial = wcs.Transformation("supergalactic j2000 j2000", "equatorial")
# RA, DEC = ((sgl, sgb))
super2galactic = wcs.Transformation("supergalactic j2000 j2000", "galactic")
# gl, gb = tran((sgl, sgb))

# %%
df["RA"] = df.apply(lambda x: super2celestial((x.SGL,x.SGB))[0], axis=1)
df["DEC"] = df.apply(lambda x: super2celestial((x.SGL,x.SGB))[1], axis=1)

df["GL"] = df.apply(lambda x: super2galactic((x.SGL,x.SGB))[0], axis=1)
df["GB"] = df.apply(lambda x: super2galactic((x.SGL,x.SGB))[1], axis=1)

df[cc].head()
# Out:
#       DM_av  eDM_av     Vcmb          RA        DEC          GL         GB  \
# PGC
# 12   35.121    0.41   6179.0    0.035972  -6.373908   90.192153 -65.929994
# 14   36.221    0.38  11474.0  359.980535   8.184610  101.660038 -52.546451
# 16   34.781    0.45   5354.0    0.047049  -5.158708   91.600561 -64.865477
# 35      NaN     inf      NaN         NaN        NaN         NaN        NaN
# 55   34.371    0.39   4466.0    0.155821  33.600952  110.949487 -28.085699
#
#           SGL      SGB   Nc  ...  DM_TFR  eDM_TFR  Nsbfo  DM_SBFm  eDM_SBFm  \
# PGC                          ...
# 12   286.4249  11.3510  NaN  ...   34.97     0.41    NaN      NaN       NaN
# 14   300.8070  15.3909  NaN  ...   36.07     0.38    NaN      NaN       NaN
# 16   287.6120  11.7030  NaN  ...   34.63     0.45    NaN      NaN       NaN
# 35        NaN      NaN  1.0  ...     NaN      NaN    NaN      NaN       NaN
# 55   327.0996  19.7763  NaN  ...   34.22     0.39    NaN      NaN       NaN
#
#      Nsbfi  DM_SBFir  eDM_SBFir  DM_SNII  eDM_SNII
# PGC
# 12     NaN       NaN        NaN      NaN       NaN
# 14     NaN       NaN        NaN      NaN       NaN
# 16     NaN       NaN        NaN      NaN       NaN
# 35     NaN       NaN        NaN      NaN       NaN
# 55     NaN       NaN        NaN      NaN       NaN
#
# [5 rows x 28 columns]

# %%
df = df[cc]
df = df[df.DM_av>0]

# %%
df.to_csv("AllGroups_CF4_components_bar_erratum.csv", sep='|')
table   = np.genfromtxt('AllGroups_CF4_components_bar_erratum.csv' , delimiter='|', 
                        filling_values=-10000, names=True, dtype=None, encoding=None)

colnames = table.dtype.names

## table is a structured array
myTable = {}
for name in table.dtype.names:
    myTable[name] = table[name]
table = myTable
## table is now a dictionary

myTable = Table()

for key in colnames:
    if key in ["SNIa"]:
        myTable.add_column(Column(data=table[key], name=key))
    elif key in ["PGC", "PGC1", "IDT14g", '1PGC']:
        myTable.add_column(Column(data=table[key], name=key, dtype=np.dtype(int))) 
    elif key in ["Vcmb", "Vmod", "Nsn", "Nfp", "Ntf", "Nsbfi", "Nsbfo", "Nc"]:
        myTable.add_column(Column(data=table[key], name=key, dtype=np.dtype(int)))
    elif key in ["SGL", "SGB", "RA", "DEC", "GL", "GB"]:
        myTable.add_column(Column(data=table[key], name=key, format='%0.4f'))
    else:
        myTable.add_column(Column(data=table[key], name=key, format='%0.3f'))

## to be used on EDD
myTable.write('allcf4_group_bar_erratum', format='ascii.fixed_width',delimiter='|', bookend=False, overwrite=True)

# %%
df.columns
# Out:
# Index(['DM_av', 'eDM_av', 'Vcmb', 'RA', 'DEC', 'GL', 'GB', 'SGL', 'SGB', 'Nc',
#        'DMcal', 'Nsn', 'DM_SNIa', 'eDM_SNIa', 'Nfp', 'DM_FP', 'eDM_FP', 'Ntf',
#        'DM_TFR', 'eDM_TFR', 'Nsbfo', 'DM_SBFm', 'eDM_SBFm', 'Nsbfi',
#        'DM_SBFir', 'eDM_SBFir', 'DM_SNII', 'eDM_SNII'],
#       dtype='object')

# %%
for cols in catalogs[1:]:
    df["delta_"+cols]=df["DM_FP"]-df["DM_"+cols]
    print(cols)

# ds = df.delta.dropna()
# dss = ds[np.abs(ds.values)>0.2]

# dss
# Out:
# FP
# TFR
# SBFm
# SBFir
# SNII

# %%
s = 'SNII'

plt.plot(df.Vcmb, df["delta_"+s], '.', color='purple')
plt.xlabel("Vcmb  [km/s]", fontsize=14)
plt.ylabel(r"$DM_{SNIa}-DM_{"+s+"}$", fontsize=14)

plt.plot([0,23000], [0,0], 'r:')

# %%
len(df)
# Out:
# 37833

# %%
df.columns
# Out:
# Index(['DM_av', 'eDM_av', 'Vcmb', 'RA', 'DEC', 'GL', 'GB', 'SGL', 'SGB', 'Nc',
#        'DMcal', 'Nsn', 'DM_SNIa', 'eDM_SNIa', 'Nfp', 'DM_FP', 'eDM_FP', 'Ntf',
#        'DM_TFR', 'eDM_TFR', 'Nsbfo', 'DM_SBFm', 'eDM_SBFm', 'Nsbfi',
#        'DM_SBFir', 'eDM_SBFir', 'DM_SNII', 'eDM_SNII', 'delta_FP', 'delta_TFR',
#        'delta_SBFm', 'delta_SBFir', 'delta_SNII'],
#       dtype='object')

# %%
df.head(30)
# Out:
#       DM_av  eDM_av     Vcmb          RA        DEC          GL         GB  \
# PGC
# 12   35.121   0.410   6179.0    0.035972  -6.373908   90.192153 -65.929994
# 14   36.221   0.380  11474.0  359.980535   8.184610  101.660038 -52.546451
# 16   34.781   0.450   5354.0    0.047049  -5.158708   91.600561 -64.865477
# 55   34.371   0.390   4466.0    0.155821  33.600952  110.949487 -28.085699
# 63   35.371   0.410   8404.0  359.993820  28.288307  109.376188 -33.225179
# 68   34.861   0.560   7358.0    0.230507 -18.958965   65.418932 -75.810094
# 70   35.451   0.390   6450.0    0.233377  20.338086  107.177913 -40.983576
# 75   36.593   0.299  11521.0    0.338780 -43.611681  331.225762 -70.661225
# 76   35.011   0.390   6566.0    0.245423  28.911812  109.805912 -32.670634
# 80   35.801   0.500   8786.0    0.269811   4.540675  100.019932 -56.074536
# 92   32.971   0.500   5626.0    0.312343  13.112513  104.514825 -47.956428
# 94   34.151   0.500   4010.0    0.503767  80.641808  120.835621  17.971849
# 96   36.691   0.410  14388.0    0.284362   6.337194  101.115530 -54.390027
# 102  34.611   0.390   4711.0    0.332350  34.525875  111.339704 -27.215414
# 109  33.948   0.283   4506.0    0.586991  31.387237  110.796685 -30.325111
# 115  36.398   0.520  14051.0    0.438590  -4.346910   93.268786 -64.318644
# 120  34.188   0.308   4007.0    0.415026  23.488112  108.411550 -37.976077
# 123  36.048   0.500  10964.0    0.400146 -14.748575   77.288486 -73.034218
# 124  34.641   0.390   5986.0    0.402697   3.505603   99.586702 -57.090424
# 128  36.161   0.460  12243.0    0.423195  32.107803  110.822641 -29.591551
# 145  35.691   0.390   9425.0    0.488391 -27.999460   25.536407 -79.003291
# 146  34.421   0.470   6003.0    0.513295  17.573914  106.549481 -43.721307
# 155  34.561   0.530   7579.0    0.516331  12.530990  104.549263 -48.570598
# 164  35.511   0.390   8289.0    0.642837   4.132417  100.395810 -56.586007
# 168  34.171   0.420   7472.0    0.704871   3.473016  100.086718 -57.226445
# 171  33.311   0.480   2296.0    0.587500  77.256910  120.154259  14.650660
# 176  35.121   0.390   5985.0    0.664337  -3.675548   94.398743 -63.811451
# 179  34.281   0.390   5539.0    0.666237   8.737100  103.000908 -52.237095
# 186  35.381   0.390   7530.0    0.693208  18.886316  107.240905 -42.497854
# 205  35.191   0.390   6943.0    0.773546  -1.913723   96.222899 -62.251912
#
#           SGL      SGB  Nc  ...  Nsbfi  DM_SBFir  eDM_SBFir  DM_SNII  \
# PGC                         ...
# 12   286.4249  11.3510 NaN  ...    NaN       NaN        NaN      NaN
# 14   300.8070  15.3909 NaN  ...    NaN       NaN        NaN      NaN
# 16   287.6120  11.7030 NaN  ...    NaN       NaN        NaN      NaN
# 55   327.0996  19.7763 NaN  ...    NaN       NaN        NaN      NaN
# 63   321.4869  19.2652 NaN  ...    NaN       NaN        NaN      NaN
# 68   274.3903   7.1770 NaN  ...    NaN       NaN        NaN      NaN
# 70   313.2488  17.7663 NaN  ...    NaN       NaN        NaN      NaN
# 75   251.2392  -1.4353 NaN  ...    NaN       NaN        NaN      NaN
# 76   322.1729  19.1316 NaN  ...    NaN       NaN        NaN      NaN
# 80   297.2349  14.1936 NaN  ...    NaN       NaN        NaN      NaN
# 92   305.8667  16.2222 NaN  ...    NaN       NaN        NaN      NaN
# 94    16.8900  17.6394 NaN  ...    NaN       NaN        NaN      NaN
# 96   299.0317  14.6401 NaN  ...    NaN       NaN        NaN      NaN
# 102  328.0932  19.7275 NaN  ...    NaN       NaN        NaN      NaN
# 109  324.8117  19.1600 NaN  ...    NaN       NaN        NaN      NaN
# 115  288.5214  11.5692 NaN  ...    NaN       NaN        NaN      NaN
# 120  316.5396  18.1559 NaN  ...    NaN       NaN        NaN      NaN
# 123  278.4600   8.4002 NaN  ...    NaN       NaN        NaN      NaN
# 124  296.2413  13.7943 NaN  ...    NaN       NaN        NaN      NaN
# 128  325.5516  19.3854 NaN  ...    NaN       NaN        NaN      NaN
# 145  265.9224   3.8953 NaN  ...    NaN       NaN        NaN      NaN
# 146  310.4600  16.9746 NaN  ...    NaN       NaN        NaN      NaN
# 155  305.3231  15.8984 NaN  ...    NaN       NaN        NaN      NaN
# 164  296.9288  13.7280 NaN  ...    NaN       NaN        NaN      NaN
# 168  296.2910  13.4948 NaN  ...    NaN       NaN        NaN      NaN
# 171   13.3827  18.2069 NaN  ...    NaN       NaN        NaN      NaN
# 176  289.2439  11.5494 NaN  ...    NaN       NaN        NaN      NaN
# 179  301.5331  14.8675 NaN  ...    NaN       NaN        NaN      NaN
# 186  311.8408  17.0660 NaN  ...    NaN       NaN        NaN      NaN
# 205  290.9997  11.9506 NaN  ...    NaN       NaN        NaN      NaN
#
#      eDM_SNII  delta_FP  delta_TFR  delta_SBFm  delta_SBFir  delta_SNII
# PGC
# 12        NaN       NaN        NaN         NaN          NaN         NaN
# 14        NaN       NaN        NaN         NaN          NaN         NaN
# 16        NaN       NaN        NaN         NaN          NaN         NaN
# 55        NaN       NaN        NaN         NaN          NaN         NaN
# 63        NaN       NaN        NaN         NaN          NaN         NaN
# 68        NaN       NaN        NaN         NaN          NaN         NaN
# 70        NaN       NaN        NaN         NaN          NaN         NaN
# 75        NaN       0.0        NaN         NaN          NaN         NaN
# 76        NaN       NaN        NaN         NaN          NaN         NaN
# 80        NaN       NaN        NaN         NaN          NaN         NaN
# 92        NaN       NaN        NaN         NaN          NaN         NaN
# 94        NaN       NaN        NaN         NaN          NaN         NaN
# 96        NaN       NaN        NaN         NaN          NaN         NaN
# 102       NaN       NaN        NaN         NaN          NaN         NaN
# 109       NaN       NaN        NaN         NaN          NaN         NaN
# 115       NaN       0.0        NaN         NaN          NaN         NaN
# 120       NaN       NaN        NaN         NaN          NaN         NaN
# 123       NaN       0.0        NaN         NaN          NaN         NaN
# 124       NaN       NaN        NaN         NaN          NaN         NaN
# 128       NaN       NaN        NaN         NaN          NaN         NaN
# 145       NaN       NaN        NaN         NaN          NaN         NaN
# 146       NaN       NaN        NaN         NaN          NaN         NaN
# 155       NaN       NaN        NaN         NaN          NaN         NaN
# 164       NaN       NaN        NaN         NaN          NaN         NaN
# 168       NaN       NaN        NaN         NaN          NaN         NaN
# 171       NaN       NaN        NaN         NaN          NaN         NaN
# 176       NaN       NaN        NaN         NaN          NaN         NaN
# 179       NaN       NaN        NaN         NaN          NaN         NaN
# 186       NaN       NaN        NaN         NaN          NaN         NaN
# 205       NaN       NaN        NaN         NaN          NaN         NaN
#
# [30 rows x 33 columns]
