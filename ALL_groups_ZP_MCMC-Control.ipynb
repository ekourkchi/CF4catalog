# %%
import sys
import time
import os
import subprocess
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress
from scipy import interpolate
from scipy import polyval, polyfit
from scipy.optimize import curve_fit
from scipy import odr
import pylab as py
from matplotlib import gridspec
import sklearn.datasets as ds
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import corner
import emcee
import scipy.optimize as op
from scipy.linalg import cholesky, inv,det
from scipy.optimize import minimize
import random
from astropy.table import Table, Column
import pandas as pd
import numpy as np
from datetime import datetime
import time

import warnings
warnings.filterwarnings("ignore")

# %%
## This function allows to execute the OS commands
def xcmd(cmd, verbose=True):
    """Runs an OS command
    :param cmd: terminal command
    :type cmd: ``str``
    :param verbose: printing the details, default True 
    :type verbose: ``boolean``
    :return: OS outputs
    :rtype: ``str``
    """

    if verbose: print('\n'+cmd)

    tmp=os.popen(cmd)
    output=''
    for x in tmp: output+=x
    if 'abort' in output:
        failure=True
    else:
        failure=tmp.close()
    if False:
        print('execution of %s failed' % cmd)
        print('error is as follows', output)
        sys.exit()
    else:
        return output

# %%
# !scp -r ehsan@arp.ifa.hawaii.edu:~/bar_files ../.

# %%
# !scp -r ehsan@arp.ifa.hawaii.edu:~/catalogs_info.dat* ../bar_files/.

# %%
# This function works with both dbtable and the catalog header name on EDD
def get_catal(catal_string, infoFile="../bar_files/catalogs_info.dat", bars_folder='../bar_files/'):
    
#     xcmd("scp -r ehsan@arp.ifa.hawaii.edu:~/catalogs_info.dat ../bar_files/.", verbose=True)

    with open(infoFile, "r") as f:
        lines = f.readlines()


        try:
            for i, line in enumerate(lines):
                if catal_string in line:
                    
                    while not "begin" in line:
                        i-=1
                        line = lines[i]
                    while not "filename" in line:
                        i+=1
                        line=lines[i]

                    fname_string = line
                    break
        except: 
            return "", []
            
        catal_columns = []
        
        try:
            while not "column" in line:
                i+=1
                line=lines[i]
            while not 'end' in line:
                catal_columns.append(line.split("=>")[1].split("|")[0].strip())
                i+=1
                line=lines[i]
                
        except:
            print("why")
            return "", []


    catal_file_name = fname_string.split("=>")[1].strip("\n").strip("")
    
#     xcmd("scp -r ehsan@arp.ifa.hawaii.edu:~/bar_files/"+catal_file_name+"  "+bars_folder+"/.", verbose=True)
    
    data = pd.read_csv(bars_folder+catal_file_name, names=catal_columns, delimiter='|')
    
    for col in catal_columns:
        if col.upper()=="PGC":
            break
    
    data.rename(columns={col:col.upper()}, inplace=True)
    data = data.set_index('PGC')
    
    # taking care of empty string
    data = data.replace(r'^\s*$', np.nan, regex=True)
    
    if "1PGC" in data.columns:
        data = data.rename(columns={"1PGC": "PGC1"})
    else:
        data["PGC1"] = data.index.values
    
    if "av_flag" in data.columns:
        data = data[data.av_flag==0]
    
    
    return data

# %%
def make_data(data, catalogs, catal_data, catal_key, catal_DM="DM", catal_eDM="eDM", delta=0):
    
    if not catal_key in catalogs and not catal_key in data:
        data[catal_key] = catal_data[["PGC1", catal_DM, catal_eDM]]
        data[catal_key] = data[catal_key].rename(columns={"PGC1": "PGC1_"+catal_key})
        data[catal_key] = data[catal_key].rename(columns={catal_DM: "DM_"+catal_key})
        data[catal_key] = data[catal_key].rename(columns={catal_eDM: "eDM_"+catal_key})
        
        catalogs.append(catal_key)
        
        data[catal_key]["DM_"+catal_key] += delta
        
    else:
        print("This catalog has been already imported ...")
        print("Use a different key than "+catal_key)
    
    return data, catalogs

# %%
data = {}
catalogs = []

# %%
catal_dbtable = "CF4 All Calibrators"
catal = get_catal(catal_dbtable)
data, catalogs = make_data(data, catalogs, catal, "Calibrators", catal_DM="DM", catal_eDM="eDM")
catal.head()
# Out:
#      PGC1     DM DelTC   eDM  Vhel     So                      Name
# PGC
# 35     35  29.73   NaN  0.10   335   t                     UGC12894
# 143   143  24.91   NaN  0.07  -125   t                          WLM
# 218   218  30.73   NaN  0.10  1050   t                      NGC7814
# 388   388  29.65   NaN  0.11   726   t                   ESO409-015
# 591   591  29.51   NaN  0.11   305   t                     UGC00064

# %%
catal_dbtable = "kcf4tfrs"
catal = get_catal(catal_dbtable)

for pgc in [5896,44982,68535]:
    try: 
        catal = catal.drop(pgc)
    except:
        pass

data, catalogs = make_data(data, catalogs, catal, "TFRs", catal_DM="DM_av", catal_eDM="eDM", delta=0.172)

catal.head()
# Out:
#       PGC1    Nest  Vcmb  Vmod   DM_zp  DM_av   eDM  av_flag  DM_cf4  eDM_cf4  \
# PGC
# 2    73150  200275  4726  4785  34.523  34.51  0.46        0   34.51     0.46
# 4      120  202766  4109  4153  33.483  33.47  0.39        0   33.49     0.49
# 12      12  210177  6195  6296  34.983  34.97  0.41        0   34.97     0.41
# 16      16  211419  5312  5386  34.643  34.63  0.45        0   34.63     0.45
# 55      55       0  4454  4506  34.233  34.22  0.39        0   33.83     0.60
#
#      ...  cf2_flag    DM_sfi   eDM_sfi  sfi_flag  DM_2mtf  eDM_2mtf  \
# PGC  ...
# 2    ...    -10000 -10000.00 -10000.00    -10000 -10000.0  -10000.0
# 4    ...         0     33.54      0.39         0 -10000.0  -10000.0
# 12   ...    -10000 -10000.00 -10000.00    -10000 -10000.0  -10000.0
# 16   ...    -10000 -10000.00 -10000.00    -10000 -10000.0  -10000.0
# 55   ...         0     34.42      0.39         0 -10000.0  -10000.0
#
#      2mtf_flag  DM_flat  eDM_flat  flat_flag
# PGC
# 2       -10000 -10000.0  -10000.0     -10000
# 4       -10000 -10000.0  -10000.0     -10000
# 12      -10000 -10000.0  -10000.0     -10000
# 16      -10000 -10000.0  -10000.0     -10000
# 55      -10000 -10000.0  -10000.0     -10000
#
# [5 rows x 26 columns]

# %%
len(catal)
# Out:
# 12220

# %%
catal_dbtable = "kcf4fps"
catal = get_catal(catal_dbtable)
data, catalogs = make_data(data, catalogs, catal, "FPs", catal_DM="DM_av", catal_eDM="eDM", delta=0.127)
catal.head()
# Out:
#      T17   PGC1    Nest   Vcmb   Vmod   DM_zp  DM_av   eDM  av_flag DM_fpsdss  \
# PGC
# 64     0  72642  200033  15324  15938  36.606  36.63  0.63        0       NaN
# 66     0  72642  200033  14725  15292  36.276  36.30  0.59        0       NaN
# 114    0  72642  200033  14397  14939  35.496  35.52  0.59        0       NaN
# 115    0    115       0  14005  14518  36.246  36.27  0.59        0       NaN
# 123    0    123  205549  10966  11282  35.886  35.91  0.56        0       NaN
#
#      ...    6dfgs_flag DM_smac eDM_smac smac_flag DM_enear eDM_enear  \
# PGC  ...
# 64   ...            0      NaN      NaN       NaN      NaN       NaN
# 66   ...            0      NaN      NaN       NaN      NaN       NaN
# 114  ...            0      NaN      NaN       NaN      NaN       NaN
# 115  ...            0      NaN      NaN       NaN      NaN       NaN
# 123  ...            0      NaN      NaN       NaN      NaN       NaN
#
#     enear_flag DM_efar eDM_efar efar_flag
# PGC
# 64         NaN     NaN      NaN       NaN
# 66         NaN     NaN      NaN       NaN
# 114        NaN     NaN      NaN       NaN
# 115        NaN     NaN      NaN       NaN
# 123        NaN     NaN      NaN       NaN
#
# [5 rows x 24 columns]

# %%
catal_dbtable = "All CF4 SNIa Samples"
catal = get_catal(catal_dbtable)
data, catalogs = make_data(data, catalogs, catal, "SNIa", catal_DM="DM_av", catal_eDM="eDM", delta=0)
catal.head()
# Out:
#                     SNIa  IDT17g  PGC1   Vcmb   Vmod   DM_zp  DM_av   eDM  \
# PGC
# 250              2006sr        0   250   6914   7042  34.912  35.05  0.13
# 282              2008hj        0   282  10921  11235  35.902  36.04  0.11
# 415              2003it        0   415   7165   7301  34.992  35.13  0.14
# 465              2000dg        0   616  11092  11415  35.912  36.05  0.20
# 515              2002hw        0   515   4796   4857  34.142  34.28  0.15
#
#        DM_pantheonplus    eDM_pantheonplus  ... DM_twins eDM_twins  \
# PGC                                         ...
# 250             35.07                0.25   ...      NaN       NaN
# 282             35.98                0.24   ...      NaN       NaN
# 415             35.14                0.25   ...      NaN       NaN
# 465                NaN                 NaN  ...      NaN       NaN
# 515                NaN                 NaN  ...      NaN       NaN
#
#        DM_avelino    eDM_avelino      RA       DE      glon     glat  \
# PGC
# 250           NaN            NaN  0.8958  23.2008  108.8693 -38.3606
# 282        35.97           0.12   1.0064 -11.1742   85.7160 -70.5385
# 415           NaN            NaN  1.4517  27.4491  110.6597 -34.3329
# 465           NaN            NaN  1.5588   8.8878  104.4513 -52.3545
# 515           NaN            NaN  1.7062   8.6285  104.5597 -52.6445
#
#           sgl      sgb
# PGC
# 250  316.3211  17.6720
# 282  282.0792   8.9703
# 415  320.8087  17.8681
# 465  301.9054  14.0485
# 515  301.6830  13.8439
#
# [5 rows x 44 columns]

# %%
catal_dbtable = "All CF4 SBF Samples"
catal = get_catal(catal_dbtable)

for pgc in [44182]:
    try: 
        print("removed PGC "+str(pgc))
        catal = catal.drop(pgc)
    except:
        pass
    
catal = catal[catal.DM_av>27]

data, catalogs = make_data(data, catalogs, catal, "SBFs", catal_DM="DM_av", catal_eDM="eDM", delta=0.105)
catal.head()
# Out:
# removed PGC 44182
#       PGC1  Vcmb  Vmod   DM_zp  DM_av   eDM  DM_virfor  eDM_virfor  DM_tonry  \
# PGC
# 218    218   701   702  30.423  30.47  0.14        0.0         0.0     30.47
# 1160  1160   804   806  31.273  31.32  0.33        0.0         0.0     31.32
# 2980  2980  1339  1344  31.433  31.48  0.47        0.0         0.0     31.48
# 4126  4126  -334  -334  27.343  27.39  0.10        0.0         0.0     27.39
# 4524  4524  1738  1746  32.353  32.40  0.35        0.0         0.0     32.40
#
#       eDM_tonry  DM_cantiello  eDM_cantiello
# PGC
# 218        0.14           0.0            0.0
# 1160       0.33           0.0            0.0
# 2980       0.47           0.0            0.0
# 4126       0.10           0.0            0.0
# 4524       0.35           0.0            0.0

# %%
catal_dbtable = "kcf4sniigroup"
catal = get_catal(catal_dbtable)
data, catalogs = make_data(data, catalogs, catal, "SNII", catal_DM="DM", catal_eDM="eDM", delta=-0.084)
catal.head()
# Out:
#         Nest  N    DMzp     DM   eDM  Vcmb       SGL      SGB         SNII  \
# PGC
# 2667       0  1  34.428  34.66  0.33  6549  270.2095  -4.9044     SN2008gr
# 5271  201212  1  34.408  34.64  0.33  6146  312.8683  -3.5009     SN2007il
# 5974  212146  1  29.568  29.80  0.97   359  314.5299  -5.3880     SN2013ej
# 6161  201134  1  34.518  34.75  0.35  5449  270.4382 -17.2497     SN2008hg
# 6415  200166  1  34.048  34.28  0.35  4893  311.3392  -9.4130     SN2001fa
#
#       PGC1
# PGC
# 2667  2667
# 5271  5271
# 5974  5974
# 6161  6161
# 6415  6415

# %%
catalogs
# Out:
# ['Calibrators', 'TFRs', 'FPs', 'SNIa', 'SBFs', 'SNII']

# %%
df = data["Calibrators"]

# %%
for cat in catalogs[1:]:
    df = df.join(data[cat], how='outer')

# %%
df
# Out:
#          PGC1_Calibrators  DM_Calibrators  eDM_Calibrators  PGC1_TFRs  \
# PGC
# 2                     NaN             NaN              NaN    73150.0
# 4                     NaN             NaN              NaN      120.0
# 12                    NaN             NaN              NaN       12.0
# 16                    NaN             NaN              NaN       16.0
# 35                   35.0           29.73              0.1        NaN
# ...                   ...             ...              ...        ...
# 9003283               NaN             NaN              NaN        NaN
# 9003285               NaN             NaN              NaN        NaN
# 9003286               NaN             NaN              NaN        NaN
# 9003287               NaN             NaN              NaN        NaN
# 9003288               NaN             NaN              NaN        NaN
#
#          DM_TFRs  eDM_TFRs  PGC1_FPs  DM_FPs  eDM_FPs  PGC1_SNIa  DM_SNIa  \
# PGC
# 2         34.682      0.46       NaN     NaN      NaN        NaN      NaN
# 4         33.642      0.39       NaN     NaN      NaN        NaN      NaN
# 12        35.142      0.41       NaN     NaN      NaN        NaN      NaN
# 16        34.802      0.45       NaN     NaN      NaN        NaN      NaN
# 35           NaN       NaN       NaN     NaN      NaN        NaN      NaN
# ...          ...       ...       ...     ...      ...        ...      ...
# 9003283      NaN       NaN       NaN     NaN      NaN  9003283.0    35.05
# 9003285      NaN       NaN       NaN     NaN      NaN    71884.0    36.98
# 9003286      NaN       NaN       NaN     NaN      NaN  9003286.0    37.95
# 9003287      NaN       NaN       NaN     NaN      NaN  6494152.0    37.65
# 9003288      NaN       NaN       NaN     NaN      NaN  9003288.0    37.17
#
#          eDM_SNIa  PGC1_SBFs  DM_SBFs  eDM_SBFs  PGC1_SNII  DM_SNII  eDM_SNII
# PGC
# 2             NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 4             NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 12            NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 16            NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 35            NaN        NaN      NaN       NaN        NaN      NaN       NaN
# ...           ...        ...      ...       ...        ...      ...       ...
# 9003283      0.10        NaN      NaN       NaN        NaN      NaN       NaN
# 9003285      0.10        NaN      NaN       NaN        NaN      NaN       NaN
# 9003286      0.10        NaN      NaN       NaN        NaN      NaN       NaN
# 9003287      0.11        NaN      NaN       NaN        NaN      NaN       NaN
# 9003288      0.10        NaN      NaN       NaN        NaN      NaN       NaN
#
# [55906 rows x 18 columns]

# %%
ss = []
for cat in catalogs[1:]:
    ss += ['PGC1_'+cat]   
df['pgc1'] = df[ss].median(axis=1)
df = df[~df['pgc1'].isna()]

# %%
df
# Out:
#          PGC1_Calibrators  DM_Calibrators  eDM_Calibrators  PGC1_TFRs  \
# PGC
# 2                     NaN             NaN              NaN    73150.0
# 4                     NaN             NaN              NaN      120.0
# 12                    NaN             NaN              NaN       12.0
# 16                    NaN             NaN              NaN       16.0
# 55                    NaN             NaN              NaN       55.0
# ...                   ...             ...              ...        ...
# 9003283               NaN             NaN              NaN        NaN
# 9003285               NaN             NaN              NaN        NaN
# 9003286               NaN             NaN              NaN        NaN
# 9003287               NaN             NaN              NaN        NaN
# 9003288               NaN             NaN              NaN        NaN
#
#          DM_TFRs  eDM_TFRs  PGC1_FPs  DM_FPs  eDM_FPs  PGC1_SNIa  DM_SNIa  \
# PGC
# 2         34.682      0.46       NaN     NaN      NaN        NaN      NaN
# 4         33.642      0.39       NaN     NaN      NaN        NaN      NaN
# 12        35.142      0.41       NaN     NaN      NaN        NaN      NaN
# 16        34.802      0.45       NaN     NaN      NaN        NaN      NaN
# 55        34.392      0.39       NaN     NaN      NaN        NaN      NaN
# ...          ...       ...       ...     ...      ...        ...      ...
# 9003283      NaN       NaN       NaN     NaN      NaN  9003283.0    35.05
# 9003285      NaN       NaN       NaN     NaN      NaN    71884.0    36.98
# 9003286      NaN       NaN       NaN     NaN      NaN  9003286.0    37.95
# 9003287      NaN       NaN       NaN     NaN      NaN  6494152.0    37.65
# 9003288      NaN       NaN       NaN     NaN      NaN  9003288.0    37.17
#
#          eDM_SNIa  PGC1_SBFs  DM_SBFs  eDM_SBFs  PGC1_SNII  DM_SNII  eDM_SNII  \
# PGC
# 2             NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 4             NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 12            NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 16            NaN        NaN      NaN       NaN        NaN      NaN       NaN
# 55            NaN        NaN      NaN       NaN        NaN      NaN       NaN
# ...           ...        ...      ...       ...        ...      ...       ...
# 9003283      0.10        NaN      NaN       NaN        NaN      NaN       NaN
# 9003285      0.10        NaN      NaN       NaN        NaN      NaN       NaN
# 9003286      0.10        NaN      NaN       NaN        NaN      NaN       NaN
# 9003287      0.11        NaN      NaN       NaN        NaN      NaN       NaN
# 9003288      0.10        NaN      NaN       NaN        NaN      NaN       NaN
#
#               pgc1
# PGC
# 2          73150.0
# 4            120.0
# 12            12.0
# 16            16.0
# 55            55.0
# ...            ...
# 9003283  9003283.0
# 9003285    71884.0
# 9003286  9003286.0
# 9003287  6494152.0
# 9003288  9003288.0
#
# [55486 rows x 19 columns]

# %%
df = df[df.DM_Calibrators>0]

# %%
len(df)
# Out:
# 122

# %%
ref = "Calibrators"
for col in catalogs:
    if col!=ref:
        df0 = df[["DM_"+ref, "DM_"+col]].dropna()

        delta = df0["DM_"+ref] - df0["DM_"+col]

        print(col, np.mean(delta), np.std(delta), len(delta))
# Out:
# TFRs -0.10287654320987644 0.5127421892722067 81
# FPs -0.10366666666666664 1.0179827547109481 3
# SNIa -0.052409090909090524 0.13815493907234233 44
# SBFs -0.20768965517241428 0.3279331411513612 29
# SNII -0.15212500000000073 0.33742793212032623 8

# %%
# df[df.DM_FPs>0]

# %%
len(df)
# Out:
# 122

# %%
df['pgc1'] = df.index.values



d = np.zeros(len(catalogs))
myDict = {}
for i, cat in enumerate(catalogs):
    myDict[cat] = d[i]

for cat in catalogs:
    df['w_'+cat] = 1./df['eDM_'+cat]**2
    df['xw_'+cat] = (df['DM_'+cat]+myDict[cat])*df['w_'+cat]

  
dg = df.groupby("pgc1").agg(["sum", "count"])

for cat in catalogs:
    dg['eDMg_'+cat] = np.sqrt(1./dg['w_'+cat]['sum'])
    dg['DMg_'+cat] = (dg['xw_'+cat]['sum'])/dg['w_'+cat]['sum']

ss = []
for cat in catalogs:
    dg['N_'+cat] = dg["DM_"+cat]['count']
    ss += ['N_'+cat, "DMg_"+cat, "eDMg_"+cat]

dg = dg[ss]
dg.replace([np.inf, -np.inf], np.nan, inplace=True)

dg.index = dg.index.astype('int')


ss = ['DMg_'+cat for cat in catalogs]+['eDMg_'+cat for cat in catalogs]
dg_ = dg[ss]

for cat in catalogs:
        dg_['gw_'+cat] = 1./dg_['eDMg_'+cat]**2

# %%
catalogs
# Out:
# ['Calibrators', 'TFRs', 'FPs', 'SNIa', 'SBFs', 'SNII']

# %%
def GfastChi2(dg, theta=None):
    
    d = theta[1]
    
    myDict = {}
    for cat in catalogs[1:]:
        myDict[cat] = d
    
    myDict[catalogs[0]] = 0   # zp

    ###########################################################
        
    for cat in catalogs:
#         dg['gw_'+cat] = 1./dg['eDMg_'+cat]**2
        dg['gxw_'+cat] = (dg['DMg_'+cat]+myDict[cat])*dg['gw_'+cat]


    sx = ['gxw_'+cat for cat in catalogs]
    sw = ['gw_'+cat for cat in catalogs]
    
    ERRave2 = 1./dg[sw].sum(axis=1)
    ave = dg[sx].sum(axis=1)*ERRave2
    
    myDict[catalogs[0]] = theta[0]
    for cat in catalogs:
        dg['gxi2_'+cat] = ((dg['DMg_'+cat]+myDict[cat]-ave)**2)/(dg_['eDMg_'+cat]**2+ERRave2)


    sxi = ['gxi2_'+cat for cat in catalogs]    
    XI2 = dg[sxi].sum(axis=1)

    return XI2.sum()

# %%
t1 =  datetime.now()

print(GfastChi2(dg_, theta=[0,1]))
###########################################
t2 =  datetime.now()
print("Execution time:")
print(t2-t1)
# Out:
# 3126.028772694216
# Execution time:
# 0:00:00.032774

# %%
dg.head()
# Out:
#      N_Calibrators DMg_Calibrators eDMg_Calibrators N_TFRs DMg_TFRs eDMg_TFRs  \
#
# pgc1
# 218              1          30.730             0.10      1   31.282      0.40
# 1014             1          26.570             0.03      1   26.212      0.41
# 1583             1          34.527             0.25      0      NaN       NaN
# 2758             1          27.800             0.02      1   27.742      0.68
# 2789             1          27.790             0.02      1   27.802      0.40
#
#      N_FPs DMg_FPs eDMg_FPs N_SNIa DMg_SNIa eDMg_SNIa N_SBFs DMg_SBFs  \
#
# pgc1
# 218      0     NaN      NaN      0      NaN       NaN      1   30.575
# 1014     0     NaN      NaN      0      NaN       NaN      0      NaN
# 1583     0     NaN      NaN      1    34.24      0.09      0      NaN
# 2758     0     NaN      NaN      0      NaN       NaN      0      NaN
# 2789     0     NaN      NaN      0      NaN       NaN      0      NaN
#
#      eDMg_SBFs N_SNII DMg_SNII eDMg_SNII
#
# pgc1
# 218       0.14      0      NaN       NaN
# 1014       NaN      0      NaN       NaN
# 1583       NaN      0      NaN       NaN
# 2758       NaN      0      NaN       NaN
# 2789       NaN      0      NaN       NaN

# %%
df
# Out:
#        PGC1_Calibrators  DM_Calibrators  eDM_Calibrators  PGC1_TFRs  DM_TFRs  \
# PGC
# 218               218.0          30.730            0.100      218.0   31.282
# 1014             1014.0          26.570            0.030     1014.0   26.212
# 1583             1583.0          34.527            0.250        NaN      NaN
# 2758             2789.0          27.800            0.020     2789.0   27.742
# 2789             2789.0          27.790            0.020     2789.0   27.802
# ...                 ...             ...              ...        ...      ...
# 69327           69327.0          30.809            0.090        NaN      NaN
# 69453           69453.0          33.246            0.117    69453.0   33.592
# 70795           70795.0          32.500            0.119    70795.0   32.682
# 71534           71534.0          33.187            0.153        NaN      NaN
# 73049           73049.0          27.750            0.080    73049.0   28.052
#
#        eDM_TFRs  PGC1_FPs  DM_FPs  eDM_FPs  PGC1_SNIa  ...    w_TFRs  \
# PGC                                                    ...
# 218        0.40       NaN     NaN      NaN        NaN  ...  6.250000
# 1014       0.41       NaN     NaN      NaN        NaN  ...  5.948840
# 1583        NaN       NaN     NaN      NaN     1583.0  ...       NaN
# 2758       0.68       NaN     NaN      NaN        NaN  ...  2.162630
# 2789       0.40       NaN     NaN      NaN        NaN  ...  6.250000
# ...         ...       ...     ...      ...        ...  ...       ...
# 69327       NaN       NaN     NaN      NaN        NaN  ...       NaN
# 69453      0.40       NaN     NaN      NaN    69453.0  ...  6.250000
# 70795      0.39       NaN     NaN      NaN    70795.0  ...  6.574622
# 71534       NaN       NaN     NaN      NaN    71534.0  ...       NaN
# 73049      0.40       NaN     NaN      NaN        NaN  ...  6.250000
#
#           xw_TFRs  w_FPs  xw_FPs      w_SNIa      xw_SNIa     w_SBFs  \
# PGC
# 218    195.512500    NaN     NaN         NaN          NaN  51.020408
# 1014   155.930993    NaN     NaN         NaN          NaN        NaN
# 1583          NaN    NaN     NaN  123.456790  4227.160494        NaN
# 2758    59.995675    NaN     NaN         NaN          NaN        NaN
# 2789   173.762500    NaN     NaN         NaN          NaN        NaN
# ...           ...    ...     ...         ...          ...        ...
# 69327         NaN    NaN     NaN         NaN          NaN  34.602076
# 69453  209.950000    NaN     NaN  123.456790  4117.283951        NaN
# 70795  214.871795    NaN     NaN   44.444444  1452.000000        NaN
# 71534         NaN    NaN     NaN   44.444444  1483.111111        NaN
# 73049  175.325000    NaN     NaN         NaN          NaN        NaN
#
#            xw_SBFs    w_SNII   xw_SNII
# PGC
# 218    1559.948980       NaN       NaN
# 1014           NaN       NaN       NaN
# 1583           NaN       NaN       NaN
# 2758           NaN       NaN       NaN
# 2789           NaN       NaN       NaN
# ...            ...       ...       ...
# 69327  1056.574394       NaN       NaN
# 69453          NaN       NaN       NaN
# 70795          NaN       NaN       NaN
# 71534          NaN       NaN       NaN
# 73049          NaN  0.961169  27.24529
#
# [122 rows x 31 columns]

# %%
len(dg_)
# Out:
# 122

# %%
dg_.head()
# Out:
#      DMg_Calibrators DMg_TFRs DMg_FPs DMg_SNIa DMg_SBFs DMg_SNII  \
#
# pgc1
# 218           30.730   31.282     NaN      NaN   30.575      NaN
# 1014          26.570   26.212     NaN      NaN      NaN      NaN
# 1583          34.527      NaN     NaN    34.24      NaN      NaN
# 2758          27.800   27.742     NaN      NaN      NaN      NaN
# 2789          27.790   27.802     NaN      NaN      NaN      NaN
#
#      eDMg_Calibrators eDMg_TFRs eDMg_FPs eDMg_SNIa  ... gxw_FPs     gxw_SNIa  \
#                                                     ...
# pgc1                                                ...
# 218              0.10      0.40      NaN       NaN  ...     NaN          NaN
# 1014             0.03      0.41      NaN       NaN  ...     NaN          NaN
# 1583             0.25       NaN      NaN      0.09  ...     NaN  4350.617284
# 2758             0.02      0.68      NaN       NaN  ...     NaN          NaN
# 2789             0.02      0.40      NaN       NaN  ...     NaN          NaN
#
#          gxw_SBFs gxw_SNII gxi2_Calibrators gxi2_TFRs gxi2_FPs gxi2_SNIa  \
#
# pgc1
# 218   1610.969388      NaN         6.893383  8.891218      NaN       NaN
# 1014          NaN      NaN         0.006511  2.413002      NaN       NaN
# 1583          NaN      NaN         5.718467       NaN      NaN  0.438209
# 2758          NaN      NaN         0.000829  1.914070      NaN       NaN
# 2789          NaN      NaN         0.007971  6.353172      NaN       NaN
#
#      gxi2_SBFs gxi2_SNII
#
# pgc1
# 218   9.988229       NaN
# 1014       NaN       NaN
# 1583       NaN       NaN
# 2758       NaN       NaN
# 2789       NaN       NaN
#
# [5 rows x 30 columns]

# %%
def lnlike(theta):
    
    xi2 = GfastChi2(dg_, theta=theta)
    
    return -0.5*xi2


def lnprior(theta):
    
    return 0.0


def lnprob(theta):
    
    lp = lnprior(theta)
    if not np.isfinite(lp) :
        return -np.inf    
    return lp + lnlike(theta)

# %%
t1 =  datetime.now()
###########################################

ndim, nwalkers = 2, 128 # 128

p0 = [np.random.randn(ndim) for i in range(nwalkers)]

sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob)

sampler.reset()
sampler.run_mcmc(p0, 5000) # 5000 for hours
samples = sampler.chain[:, 100:, :].reshape((-1, ndim))

theta = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                            zip(*np.percentile(samples, 
                            [16, 50, 84],
                            axis=0)))

###########################################
t2 =  datetime.now()
print("Execution time:")
print(t2-t1)
# Out:
# Execution time:
# 3:43:28.084289

# %%
samples[:,1]
# Out:
# array([-0.14054736, -0.14361179, -0.14361179, ..., -0.18788403,
#        -0.1722035 , -0.1722035 ])

# %%
truths=[t[0] for t in theta]
fig = corner.corner(samples, labels=["Calibrators", "ZP adjustment"], 
                    truths=truths, 
                    quantiles=[0.16, 0.5, 0.84], 
                    show_titles=True, 
                    title_kwargs={"fontsize": 12}, 
                    title_fmt=".3f")

###########################################
t2 =  datetime.now()
print("Execution time:")
print(t2-t1)
# Out:
# Execution time:
# 3:43:28.336365

# %%
npzName = "ALL_galaxy_ZP_control.npz"
np.savez(npzName, samples)
npzfile = np.load(npzName)
print("npz attributes: ", npzfile.files)
NPZsamples = npzfile['arr_0']
# Out:
# npz attributes:  ['arr_0']

# %%
mean = np.mean(NPZsamples[:,0])

mean
# Out:
# -0.00023688132991922083
