# %%
import sys
import time
import os
import subprocess
import math
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table, Column 
from scipy.stats import linregress
from scipy import interpolate
from scipy import polyval, polyfit
from scipy.optimize import curve_fit
from scipy import odr
import pylab as py
from matplotlib import gridspec
import sklearn.datasets as ds
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import corner
import emcee
import scipy.optimize as op
from scipy.linalg import cholesky, inv,det
from scipy.optimize import minimize
import random
from astropy.table import Table, Column
import pandas as pd
import numpy as np
from datetime import datetime
import time

# %%
#################################################################
def Vh2V3k(el,b, Vh):
  
    alpha = np.pi / 180.
    cosb = np.cos(b*alpha)
    sinb = np.sin(b*alpha)
    cosl = np.cos(el*alpha)
    sinl = np.sin(el*alpha)
    
    v3k = Vh-25.2*cosl*cosb-245.7*sinl*cosb+276.8*sinb

    return v3k

#################################################################

def Vcmb2Vmod(Vcmb, omegam=0.27):
    
    omegal=1.-omegam
    c=299800.
    z=Vcmb/c
    q0=0.5*(omegam-2.*omegal)
    fmod=1.+0.5*(1.-q0)*z-(1./6)*(1.-q0-3.*q0**2+1.)*z**2
    Vmod=c*z*fmod

    return Vmod
#################################################################

def Vh2Vls(el,b, Vh):
  
    alpha = np.pi / 180.
    cosb = np.cos(b*alpha)
    sinb = np.sin(b*alpha)
    cosl = np.cos(el*alpha)
    sinl = np.sin(el*alpha)
    
    vls = Vh-26.*cosl*cosb+317.*sinl*cosb-8.*sinb

    return vls
#################################################################

# %%
df = pd.read_csv('TFR_CF4_components_bar', delimiter='|')
df = df.rename(columns=lambda x: x.strip())

df_TFR = df.set_index('PGC')
df_TFR = df_TFR.rename(columns={"Nest": "Nest_TFR"})
df_TFR = df_TFR.rename(columns={"PGC1": "PGC1_TFR"})
df_TFR = df_TFR.rename(columns={"Vcmb": "Vcmb_TFR"})
df_TFR = df_TFR.rename(columns={"DM_av": "DM_TFR"})
df_TFR = df_TFR.rename(columns={"eDM_av": "eDM_TFR"})

df_TFR = df_TFR[df_TFR["av_flag"]==0]

df_TFR.head()
# Out:
#      PGC1_TFR  Nest_TFR  Vcmb_TFR  Vmod  DM_TFR  eDM_TFR  av_flag  DM_cf4  \
# PGC
# 2       73150    200275      4726  4785   34.24     0.39        0   34.24
# 4         120    202766      4109  4153   33.39     0.22        0   33.29
# 12         12    210177      6195  6296   35.03     0.39        0   35.03
# 16         16    211419      5312  5386   34.70     0.37        0   34.70
# 55         55         0      4454  4506   34.18     0.22        0   34.00
#
#      eDM_cf4  cf4_flag  ...  cf2_flag  DM_sfi  eDM_sfi  sfi_flag  DM_2mtf  \
# PGC                     ...
# 2       0.39         0  ...         0    0.00     0.00         0      0.0
# 4       0.37         0  ...         0   33.52     0.39         0      0.0
# 12      0.39         0  ...         0    0.00     0.00         0      0.0
# 16      0.37         0  ...         0    0.00     0.00         0      0.0
# 55      0.37         0  ...         0   34.40     0.39         0      0.0
#
#      eDM_2mtf  2mtf_flag  DM_flat  eDM_flat  flat_flag
# PGC
# 2         0.0          0      0.0       0.0          0
# 4         0.0          0      0.0       0.0          0
# 12        0.0          0      0.0       0.0          0
# 16        0.0          0      0.0       0.0          0
# 55        0.0          0      0.0       0.0          0
#
# [5 rows x 25 columns]

# %%
df = pd.read_csv('6dfgs.csv', delimiter='|')
df = df.rename(columns=lambda x: x.strip())
df_6dfgs = df.set_index('PGC')

ln10 = np.log(10.)
df_6dfgs['DM_6dfgs']  = (5*np.log10(df_6dfgs["D75"])+25.)
df_6dfgs['eDM_6dfgs'] = 5.*df_6dfgs["feD"]/ln10
df_6dfgs = df_6dfgs.rename(columns={"Nest": "Nest_6dfgs"})
df_6dfgs = df_6dfgs.rename(columns={"Vcmb": "Vcmb_6dfgs"})
df_6dfgs = df_6dfgs.rename(columns={"PGC1": "PGC1_6dfgs"})

df_6dfgs.head()
# Out:
#      PGC1_6dfgs  Nest_6dfgs             Name  Vcmb_6dfgs    Vgp    D75   D100  \
# PGC
# 27           27           0  g0000235-065610       10920  10920  145.5  109.2
# 40           40      209793  g0000356-014547        6956   6956  116.4   87.3
# 51          142      201987  g0000358-403432       14746  14746  248.6  186.5
# 64        72642      200033  g0000523-355037       15324  14646  222.3  166.7
# 66        72642      200033  g0000532-355911       14725  14646  191.0  143.2
#
#       feD      DzDh       eDz      skew      RA       DE     Vg    Gp  \
# PGC
# 27   0.27  0.015698  0.105029 -0.021398  0.0978  -6.9362  10920    -1
# 40   0.31 -0.088660  0.118089  0.016330  0.1485  -1.7632   6956    -1
# 51   0.42 -0.081111  0.152326  0.015862  0.1489 -40.5756  14746    -1
# 64   0.29 -0.034659  0.110224  0.010894  0.2181 -35.8437  14646  1261
# 66   0.27  0.030506  0.103811 -0.028422  0.2216 -35.9863  14646  1261
#
#       DM_6dfgs  eDM_6dfgs
# PGC
# 27   35.814315   0.586298
# 40   35.329765   0.673156
# 51   36.977506   0.912018
# 64   36.734697   0.629727
# 66   36.405167   0.586298

# %%
df = pd.read_csv('all_cf2_fp.csv', delimiter='|')
df = df.rename(columns=lambda x: x.strip())
df_cf2fp = df.set_index('PGC')

for suffix in ["smc","enr","far"]:
    df_cf2fp = df_cf2fp.rename(columns={"DM"+suffix: "DM_"+suffix})
    df_cf2fp["eDM_"+suffix] = 0.50
    df_cf2fp["DM_"+suffix][df_cf2fp["DM_"+suffix]==0] = np.nan
    df_cf2fp["eDM_"+suffix][df_cf2fp["DM_"+suffix].isna()] = np.nan
    df_cf2fp["PGC1_"+suffix] = df_cf2fp["PGC1"]
    df_cf2fp["Nest_"+suffix] = df_cf2fp["Nest"]
    df_cf2fp["Vcmb_"+suffix] = df_cf2fp["Vcmb"]


del df_cf2fp['PGC1']
del df_cf2fp['Nest']
del df_cf2fp['Vcmb']
# Out:
# /home/ehsan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ehsan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
how = 'outer'
df = df_TFR.join(df_6dfgs, lsuffix='_TFR', rsuffix='_6dfgs', how=how)
df = df.join(df_cf2fp, lsuffix='_l', rsuffix='_cf2fp', how=how)


for col in df.columns:
    if col.split('_')[0]=='PGC1' and col!='PGC1_TFR':
        df['PGC1_TFR'] = df['PGC1_TFR'].fillna(df[col])
        
for col in df.columns:
    if col.split('_')[0]=='Nest' and col!='Nest_TFR':
        df['Nest_TFR'] = df['Nest_TFR'].fillna(df[col])


catalogs = ["TFR", "6dfgs", "smc", "enr", "far"]

ss = []
for cat in catalogs:
    ss += ['PGC1_'+cat, 'Nest_'+cat, "DM_"+cat, "eDM_"+cat, "Vcmb_"+cat]

df = df[ss]

ss = []
for cat in catalogs:
    ss += ['PGC1_'+cat]   
df['pgc1'] = df[ss].median(axis=1)
df = df[~df['pgc1'].isna()]



print(len(df))

df.head()
# Out:
# 22513
#      PGC1_TFR  Nest_TFR  DM_TFR  eDM_TFR  Vcmb_TFR  PGC1_6dfgs  Nest_6dfgs  \
# PGC
# 2     73150.0  200275.0   34.24     0.39    4726.0         NaN         NaN
# 4       120.0  202766.0   33.39     0.22    4109.0         NaN         NaN
# 12       12.0  210177.0   35.03     0.39    6195.0         NaN         NaN
# 16       16.0  211419.0   34.70     0.37    5312.0         NaN         NaN
# 27       27.0       0.0     NaN      NaN       NaN        27.0         0.0
#
#       DM_6dfgs  eDM_6dfgs  Vcmb_6dfgs  ...  Nest_enr  DM_enr  eDM_enr  \
# PGC                                    ...
# 2          NaN        NaN         NaN  ...       NaN     NaN      NaN
# 4          NaN        NaN         NaN  ...       NaN     NaN      NaN
# 12         NaN        NaN         NaN  ...       NaN     NaN      NaN
# 16         NaN        NaN         NaN  ...       NaN     NaN      NaN
# 27   35.814315   0.586298     10920.0  ...       NaN     NaN      NaN
#
#      Vcmb_enr  PGC1_far  Nest_far  DM_far  eDM_far  Vcmb_far     pgc1
# PGC
# 2         NaN       NaN       NaN     NaN      NaN       NaN  73150.0
# 4         NaN       NaN       NaN     NaN      NaN       NaN    120.0
# 12        NaN       NaN       NaN     NaN      NaN       NaN     12.0
# 16        NaN       NaN       NaN     NaN      NaN       NaN     16.0
# 27        NaN       NaN       NaN     NaN      NaN       NaN     27.0
#
# [5 rows x 26 columns]

# %%
for cat in catalogs:
    df['Vmod_'+cat] = Vcmb2Vmod(df['Vcmb_'+cat])
    logD = (df['DM_'+cat]-25)/5.
    df['logH_'+cat] = np.log10(df['Vmod_'+cat]) - logD 
    
    print cat, 10**df['logH_'+cat][df['Vmod_'+cat]>4000].median()
# Out:
# TFR 75.145684867
# 6dfgs 73.5127876244
# smc 76.7370479949
# enr 76.2225616604
# far 80.3615247509
# /home/ehsan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log10
#   after removing the cwd from sys.path.

# %%
sigmaClips = {}

for i in range(1):
    for cat in catalogs:

        logH = df['logH_'+cat]
        med = logH[df['Vmod_'+cat]>4000].median()
        stdev = logH[df['Vmod_'+cat]>4000].std()
        
#         print cat, 10**med
        
        if not cat in sigmaClips:
                sigmaClips[cat] = []
        sigmaClips[cat] += list(df[(logH > med+3.5*stdev) | (logH < med-3.5*stdev)].index.values)
        df['DM_'+cat][(logH > med+3.5*stdev) | (logH < med-3.5*stdev)] = np.nan
        df['eDM_'+cat][(logH > med+3.5*stdev) | (logH < med-3.5*stdev)] = np.nan
        df['logH_'+cat][(logH > med+3.5*stdev) | (logH < med-3.5*stdev)] = np.nan

# %%
myDict = {}
myDict['TFR'] = 0

for cat in catalogs[1:]:

        delta = df['DM_TFR'] - df['DM_'+cat]

        stdev = delta.std()
        med   = delta.median()
        myDict[cat] = med

# %%
for cat in sigmaClips:
    print cat, len(sigmaClips[cat])

myDict
# Out:
# far 0
# enr 2
# 6dfgs 17
# smc 1
# TFR 65
# {'6dfgs': 0.46300242690708515,
#  'TFR': 0,
#  'enr': 0.8200000000000003,
#  'far': -0.7000000000000028,
#  'smc': 1.259999999999998}

# %%
d = np.zeros(len(catalogs))
myDict = {}
for i, cat in enumerate(catalogs):
    myDict[cat] = d[i]

for cat in catalogs:
    df['w_'+cat] = 1./df['eDM_'+cat]**2
    df['xw_'+cat] = (df['DM_'+cat]+myDict[cat])*df['w_'+cat]

  
dg = df.groupby("pgc1").agg(["sum", "count"])

for cat in catalogs:
    dg['eDMg_'+cat] = np.sqrt(1./dg['w_'+cat]['sum'])
    dg['DMg_'+cat] = (dg['xw_'+cat]['sum'])/dg['w_'+cat]['sum']

ss = []
for cat in catalogs:
    dg['N_'+cat] = dg["DM_"+cat]['count']
    ss += ['N_'+cat, "DMg_"+cat, "eDMg_"+cat]

dg = dg[ss]
dg.replace([np.inf, -np.inf], np.nan, inplace=True)

dg.index = dg.index.astype('int')


ss = ['DMg_'+cat for cat in catalogs]+['eDMg_'+cat for cat in catalogs]
dg_ = dg[ss]

for cat in catalogs:
        dg_['gw_'+cat] = 1./dg_['eDMg_'+cat]**2
# Out:
# /home/ehsan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def GfastChi2(dg, theta=None):
    
    if theta is None:
        d = np.zeros(len(catalogs))
    else:
        theta = np.asarray(theta)
        d = np.concatenate((np.zeros(1), theta[1:]))
    
    myDict = {}
    for i, cat in enumerate(catalogs):
        myDict[cat] = d[i]

    ###########################################################
        
    for cat in catalogs:
#         dg['gw_'+cat] = 1./dg['eDMg_'+cat]**2
        dg['gxw_'+cat] = (dg['DMg_'+cat]+myDict[cat])*dg['gw_'+cat]


    sx = ['gxw_'+cat for cat in catalogs]
    sw = ['gw_'+cat for cat in catalogs]
    
    ERRave2 = 1./dg[sw].sum(axis=1)
    ave = dg[sx].sum(axis=1)*ERRave2
    
    myDict[catalogs[0]] = theta[0]
    for cat in catalogs:
        dg['gxi2_'+cat] = ((dg['DMg_'+cat]+myDict[cat]-ave)**2)/(dg_['eDMg_'+cat]**2+ERRave2)


    sxi = ['gxi2_'+cat for cat in catalogs]    
    XI2 = dg[sxi].sum(axis=1)

    return XI2.sum()

# %%
t1 =  datetime.now()

print GfastChi2(dg_, theta=range(len(catalogs)))

###########################################
t2 =  datetime.now()
print("Execution time:")
print(t2-t1)
# Out:
# 21438.35011880302
# Execution time:
# 0:00:00.111554

# %%
len(dg_)
# Out:
# 15998

# %%
len(df)
# Out:
# 22513

# %%
def lnlike(theta):
    
    xi2 = GfastChi2(dg_, theta=theta)
    
    return -0.5*xi2


def lnprior(theta):
    
    return 0.0


def lnprob(theta):
    
    lp = lnprior(theta)
    if not np.isfinite(lp) :
        return -np.inf    
    return lp + lnlike(theta)

# %%
t1 =  datetime.now()
###########################################

ndim, nwalkers = len(catalogs), 64

p0 = [np.random.randn(ndim) for i in range(nwalkers)]

sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob)

sampler.reset()
sampler.run_mcmc(p0, 10000)
samples = sampler.chain[:, 1000:, :].reshape((-1, ndim))

theta = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                            zip(*np.percentile(samples, 
                            [16, 50, 84],
                            axis=0)))

truths=[t[0] for t in theta]
fig = corner.corner(samples, labels=catalogs, 
                    truths=truths, 
                    quantiles=[0.16, 0.5, 0.84], 
                    show_titles=True, 
                    title_kwargs={"fontsize": 12}, 
                    title_fmt=".3f")

###########################################
t2 =  datetime.now()
print("Execution time:")
print(t2-t1)
# Out:
# Execution time:
# 10:27:50.712588

# %%
theta = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                            zip(*np.percentile(samples, 
                            [16, 50, 84],
                            axis=0)))

truths=[t[0] for t in theta]

labels = ['           '+r'$\Delta\/ \mu_{'+cat+'}$' for cat in catalogs]

fig = corner.corner(samples, labels=labels, 
                    truths=truths, truth_color='blue',
                    levels=(1-np.exp(-1./8),1-np.exp(-0.5),1-np.exp(-0.5*4),1-np.exp(-0.5*9)),
                    show_titles=True, fill_contours=True, plot_density=True,
                    quantiles=[0.16, 0.84], 
                    scale_hist=False,space=0, 
                    title_kwargs={"fontsize": 18}, 
                    title_fmt=".3f",
                    range=[(t-0.20,t+0.20) for t in truths]
                   )

m = 0 
n_cat = len(catalogs)
i_cat = 0
for ax in fig.get_axes():
    ax.tick_params(axis='both', labelsize=12)
    
    lbl = ax.xaxis.get_label()
    lbl.set_fontsize(22)
    txt = lbl.get_text().strip()
    lbl.set_text(txt)
    lbl.set_linespacing(50)
    lbl = ax.yaxis.get_label()
    lbl.set_fontsize(22)
    txt = lbl.get_text().strip()
    lbl.set_text(txt)    
    
    
    ax.tick_params(which='major', length=3, width=1., direction='out')
    
    Ylm = ax.get_ylim() ; Xlm = ax.get_xlim()
    x0 = -0.1*Xlm[0]+1.1*Xlm[1]
    
    if m%(n_cat+1)==0:
        y0 = 0.2*Ylm[0]+0.80*Ylm[1]
        dx = df[['DM_'+catalogs[i_cat]]].dropna()
        ax.text(x0,y0, r"$total: $"+str(len(dx)), fontsize=16, color='k')
        
        y0 = 0.35*Ylm[0]+0.65*Ylm[1]
        other_DMs = ["DM_"+c for c in catalogs if c != catalogs[i_cat]]
        
        df["sumDM"] = df[other_DMs].sum(axis=1)
        df["sumDM"][df["sumDM"]==0] = np.nan
        
        dx = df[['sumDM', 'DM_'+catalogs[i_cat]]].dropna()       
        ax.text(x0,y0, r"$intersect: $"+str(len(dx)), fontsize=16, color='maroon')
        i_cat += 1


    m+=1

# %%
truths
# Out:
# [-0.07146960866957416,
#  -0.011928643392961367,
#  -0.01670248956773119,
#  0.06789054732870944]

# %%
def GfastChi2_(dg, theta):
    
    if True:
        d = np.zeros(len(catalogs))
        d[0] = theta[0]
        d[1:] = truths
    
    myDict = {}
    for i, cat in enumerate(catalogs):
        myDict[cat] = d[i]

    ###########################################################
        
    for cat in catalogs:
#         dg['gw_'+cat] = 1./dg['eDMg_'+cat]**2
        dg['gxw_'+cat] = (dg['DMg_'+cat]+myDict[cat])*dg['gw_'+cat]


    sx = ['gxw_'+cat for cat in catalogs]
    sw = ['gw_'+cat for cat in catalogs]
    
    ERRave2 = 1./dg[sw].sum(axis=1)
    ave = dg[sx].sum(axis=1)*ERRave2
    
    
    for cat in catalogs:
        dg['gxi2_'+cat] = ((dg['DMg_'+cat]+myDict[cat]-ave)**2)/(dg_['eDMg_'+cat]**2+ERRave2)


    sxi = ['gxi2_'+cat for cat in catalogs]    
    XI2 = dg[sxi].sum(axis=1)

    return XI2.sum()



def lnlike2(theta):
    
    xi2 = GfastChi2_(dg_, theta)
    
    return -0.5*xi2

def lnprob2(theta):
    
    lp = lnprior(theta)
    if not np.isfinite(lp) :
        return -np.inf    
    return lp + lnlike2(theta)

# %%
t1 =  datetime.now()
###########################################

ndim_, nwalkers_ = 1, 32

p0_ = [np.random.randn(ndim_) for i in range(nwalkers_)]

sampler_ = emcee.EnsembleSampler(nwalkers_, ndim_, lnprob2)

sampler_.reset()
sampler_.run_mcmc(p0_, 2000)
samples_ = sampler_.chain[:, 500:, :].reshape((-1, ndim_))

theta_ = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                            zip(*np.percentile(samples, 
                            [16, 50, 84],
                            axis=0)))

truths_=[t[0] for t in theta]
fig = corner.corner(samples_, 
                    truths=truths_, 
                    quantiles=[0.16, 0.5, 0.84], 
                    show_titles=True, 
                    title_kwargs={"fontsize": 12}, 
                    title_fmt=".3f")

###########################################
t2 =  datetime.now()
print("Execution time:")
print(t2-t1)
# Out:
# Execution time:
# 0:59:18.416968
